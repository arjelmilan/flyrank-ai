# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/arjelmilan/flyrank-ai/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# *Refresh / Content Opportunity Scoring*
#
# Can future content decline be predicted from prior-period search, engagement, and content signals well enough to improve the prioritization of pages for human review?

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# It helps in finding out which pages should the content/review team prioritize first for review.
#
# Content/SEO specialists or editors act on the ranked output.
#
# If our model is not providing better results then team may miss an important page that could have benefited from timely attention, potentially allowing its visibility, traffic, CTR, or engagement to deteriorate further.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/arjelmilan/flyrank-ai/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(url)

print("Dataset shape:", df.shape)
display(df.head())
# Out:
# Dataset shape: (30000, 44)
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %%
print(df.columns.to_list())
# Out:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']

# %%
total_pages = len(df)

declining_pages = (df["trend_direction"] == "down").sum()

visible_declining = (
    (df["trend_direction"] == "down") &
    (df["impressions_90d"] >= 500)
).sum()

print(f"Total pages: {total_pages:,}")
print(f"Declining pages: {declining_pages:,} "
      f"({declining_pages / total_pages * 100:.2f}%)")
print(f"Visible + declining pages: {visible_declining:,} "
      f"({visible_declining / total_pages * 100:.2f}%)")
# Out:
# Total pages: 30,000
# Declining pages: 16,262 (54.21%)
# Visible + declining pages: 9,961 (33.20%)

# %%
review_candidates = df[
    (df["impressions_90d"] >= 500) &
    (df["sessions_90d"] >= 10) &
    (df["trend_direction"] == "down")
]

print(f"High-evidence declining pages: {len(review_candidates):,}")
print(f"Share of dataset: "
      f"{len(review_candidates) / total_pages * 100:.2f}%")
# Out:
# High-evidence declining pages: 6,687
# Share of dataset: 22.29%

# %%
# Basic dataset size
n_pages = len(df)

# Declining pages
declining = (df["trend_direction"] == "down").sum()
declining_pct = declining / n_pages * 100

# Pages with meaningful search visibility
visible_pages = (df["impressions_90d"] >= 500).sum()
visible_pct = visible_pages / n_pages * 100

print(f"Total pages: {n_pages:,}")
print(f"Declining pages: {declining:,} ({declining_pct:.1f}%)")
print(f"Pages with >=500 impressions: {visible_pages:,} ({visible_pct:.1f}%)")
# Out:
# Total pages: 30,000
# Declining pages: 16,262 (54.2%)
# Pages with >=500 impressions: 16,726 (55.8%)

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# Our work will provide observed and directional evidence about which pages exhibit signals associated with content-performance decline and will produce a ranked decision-support queue for human review. We can evaluate whether the model improves prioritization over simple rules using held-out historical data. However, we will not claim causal effects from content changes, guarantee that recommended pages will recover, or claim to predict Google's ranking decisions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
